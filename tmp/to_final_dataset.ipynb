# %%
import pandas as pd
from glob import glob

# %%
chunks = glob("phenodash/data/interim/*.parquet")

# %%
final = pd.concat((pd.read_parquet(chunk) for chunk in chunks), axis=0)

# %%
final.shape
# Out:
# (16762, 60483)

# %%
final.to_parquet("phenodash/data/processed/complete_dataset.parquet")

# %%
final.head()
# Out:
# 0                                     ENSG00000242268.2  ENSG00000270112.3  \
# 0000772b-773d-4cf8-8baf-0e1e6dbf55e8           0.102577           1.167097
# 00059756-2eca-4bfe-9cd0-92faee36ddc0           0.109657           0.076076
# 00068002-f4f0-4610-bfe6-67169c760d21           0.000000           0.000000
# 0006cd63-2533-46d9-b58d-98fadea87b49           0.000000           0.010832
# 000c6318-cac2-483b-bd7d-95d4e251e64b           0.000000           0.006600
#
# 0                                     ENSG00000167578.15  ENSG00000273842.1  \
# 0000772b-773d-4cf8-8baf-0e1e6dbf55e8            2.515833                0.0
# 00059756-2eca-4bfe-9cd0-92faee36ddc0            3.262965                0.0
# 00068002-f4f0-4610-bfe6-67169c760d21            2.975856                0.0
# 0006cd63-2533-46d9-b58d-98fadea87b49            5.518563                0.0
# 000c6318-cac2-483b-bd7d-95d4e251e64b            4.549200                0.0
#
# ...

# %%
final.memory_usage(deep=True).sum()/1000000000
# Out:
# 8.112615658

# %%
size
